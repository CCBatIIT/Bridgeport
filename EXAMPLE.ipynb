# %%
from Bridgeport import Bridgeport
import os
from datetime import datetime
# Out:
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/Bio/Application/__init__.py:40: BiopythonDeprecationWarning: The Bio.Application modules and modules relying on it have been deprecated.
#
# Due to the on going maintenance burden of keeping command line application
# wrappers up to date, we have decided to deprecate and eventually remove these
# modules.
#
# We instead now recommend building your command line and invoking it directly
# with the subprocess module.
#   warnings.warn(

# %%
# Initialize object
start_time = datetime.now()
BP = Bridgeport(input_json='peptide_example_input.json')
BP.run()
end_time = datetime.now()
print('Time to run notebook:', end_time - start_time)
# Out:
# 02/13/2024 00:47:06//Welcome to Bridgeport.
# 02/13/2024 00:47:06//Found input parameters.
# 02/13/2024 00:47:06//working_dir:
# 02/13/2024 00:47:06//working_dir: /home/exouser/Bridgeport/tests
# 02/13/2024 00:47:06//ligand:
# 02/13/2024 00:47:06//	lig_resname: False
# 02/13/2024 00:47:06//	peptide_chain: P
# 02/13/2024 00:47:06//	peptide_fasta: /home/exouser/Bridgeport/tests/fasta/PTH.fasta
# 02/13/2024 00:47:06//protein:
# 02/13/2024 00:47:06//	input_pdb_dir: /home/exouser/Bridgeport/tests/input_pdb
# 02/13/2024 00:47:06//	input_pdb: 7vvk.pdb
# 02/13/2024 00:47:06//	chains: R
# 02/13/2024 00:47:06//RepairProtein:
# 02/13/2024 00:47:06//	working_dir: /home/exouser/Bridgeport/tests/modeller_intermediates
# 02/13/2024 00:47:06//	fasta_path: /home/exouser/Bridgeport/tests/fasta/PTHR1.fasta
# 02/13/2024 00:47:06//	tails: [30, 479]
# 02/13/2024 00:47:06//	loops: [[49, 127], [157, 163], [174, 179], [246, 278], [392, 398]]
# 02/13/2024 00:47:06//	secondary_template: False
# 02/13/2024 00:47:06//environment:
# 02/13/2024 00:47:06//	membrane: True
# 02/13/2024 00:47:06//	alignment_ref: /home/exouser/Bridgeport/tests/OPM/7vvk.pdb
# 02/13/2024 00:47:06//Found directory for aligned input structures: /home/exouser/Bridgeport/tests/aligned_input_pdb
# 02/13/2024 00:47:06//Found references structure /home/exouser/Bridgeport/tests/OPM/7vvk.pdb
# 02/13/2024 00:47:06//Found input structure: /home/exouser/Bridgeport/tests/input_pdb/7vvk.pdb
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/coordinates/PDB.py:453: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/coordinates/PDB.py:777: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/MDAnalysis/coordinates/PDB.py:1153: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# 02/13/2024 00:47:06//Found directory for protein structures: /home/exouser/Bridgeport/tests/proteins
# 02/13/2024 00:47:06//Found directory for protein structures: /home/exouser/Bridgeport/tests/proteins
# 02/13/2024 00:47:06//Separated chain R from input structure
# 02/13/2024 00:47:06//Separated ligand P from input structure
# 02/13/2024 00:47:06//Welcome to RepairProtein
# 02/13/2024 00:47:06//Protein to repair: /home/exouser/Bridgeport/tests/proteins/7vvk.pdb
# 02/13/2024 00:47:06//Template sequence: /home/exouser/Bridgeport/tests/fasta/PTHR1.fasta
# 02/13/2024 00:47:06//Modeller intermediates will be written to: /home/exouser/Bridgeport/tests/modeller_intermediates
#
#                          MODELLER 10.5, 2024/01/19, r12711
#
#      PROTEIN STRUCTURE MODELLING BY SATISFACTION OF SPATIAL RESTRAINTS
#
#
#                      Copyright(c) 1989-2024 Andrej Sali
#                             All Rights Reserved
#
#                              Written by A. Sali
#                                with help from
#               B. Webb, M.S. Madhusudhan, M-Y. Shen, G.Q. Dong,
#           M.A. Marti-Renom, N. Eswar, F. Alber, M. Topf, B. Oliva,
#              A. Fiser, R. Sanchez, B. Yerkovich, A. Badretdinov,
#                      F. Melo, J.P. Overington, E. Feyfant
#                  University of California, San Francisco, USA
#                     Rockefeller University, New York, USA
#                       Harvard University, Cambridge, USA
#                    Imperial Cancer Research Fund, London, UK
#               Birkbeck College, University of London, London, UK
#
#
# Kind, OS, HostName, Kernel, Processor: 4, Linux willingly-wallowing-wasp 5.15.0-92-generic x86_64
# Date and time of compilation         : 2024/01/20 00:32:05
# MODELLER executable type             : x86_64-intel8
# Job starting time (YY/MM/DD HH:MM:SS): 2024/02/13 00:47:05
# /home/exouser/miniconda3/envs/prep/lib/python3.12/site-packages/mdtraj/formats/pdb/pdbfile.py:200: UserWarning: Unlikely unit cell vectors detected in PDB file likely resulting from a dummy CRYST1 record. Discarding unit cell vectors.
#   warnings.warn('Unlikely unit cell vectors detected in PDB file likely '
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# read_to_681_> topology.submodel read from topology file:        3
# patch_s_522_> Number of disulfides patched in MODEL:        1
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    40987    36735
# 8 (of 4677 total) atoms selected for optimization
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      593
# Number of all, selected real atoms                :     4677       8
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    36735      28
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):        5
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :           2.1123
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :       8       0      0   0.002   0.002     0.76804E-02   1.000
#  2 Bond angle potential               :      10       0      0   0.507   0.507     0.37322E-01   1.000
#  3 Stereochemical cosine torsion poten:       3       0      0  31.278  31.278     0.28697       1.000
#  4 Stereochemical improper torsion pot:       2       0      0   0.609   0.609     0.12457E-01   1.000
#  5 Soft-sphere overlap restraints     :       5       0      0   0.005   0.005     0.12153E-01   1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:       1       0      0   1.593   1.593     0.29927E-01   1.000
# 14 Sidechain Chi_1 dihedral restraints:       1       0      0 101.448 101.448     0.39331       1.000
# 15 Sidechain Chi_2 dihedral restraints:       1       0      0   2.120   2.120     0.38145E-01   1.000
# 16 Sidechain Chi_3 dihedral restraints:       1       0      0   8.104   8.104     0.43931       1.000
# 17 Sidechain Chi_4 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :       0       0      0   0.000   0.000      0.0000       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:       1       1      0   5.962 *******     0.85498       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :       0       0      0   0.000   0.000      0.0000       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: 7vvk_fill.V99990001
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:     103.6167
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 25                           : Phi/Psi pair of dihedral restraints
# List of the RVIOL violations larger than   :       6.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  16645   1M   2G C   N       7    9  -81.29  -80.20    5.96    0.18   82.20 -123.08    7.23
#     1          2G   2G N   CA      9   10  179.96  174.10                    8.50
#
#
# report______> Distribution of short non-bonded contacts:
#
#   serious non-bonded atom clash:   106  111   2.035
#   serious non-bonded atom clash:   155 3490   2.030
#   serious non-bonded atom clash:   163 3490   2.252
#   serious non-bonded atom clash:   164 3490   1.583
#   serious non-bonded atom clash:   167 3488   1.630
#   serious non-bonded atom clash:   167 3489   1.158
#   serious non-bonded atom clash:   167 3490   2.189
#   serious non-bonded atom clash:   167 3491   1.317
#   serious non-bonded atom clash:   168 3488   1.615
#   serious non-bonded atom clash:   168 3489   2.177
#   serious non-bonded atom clash:   168 3491   2.079
#   serious non-bonded atom clash:   169 3455   2.124
#   serious non-bonded atom clash:   169 3491   2.232
#   serious non-bonded atom clash:   170 3488   1.658
#   serious non-bonded atom clash:   171 1444   1.739
#   serious non-bonded atom clash:   172  177   2.257
#   serious non-bonded atom clash:   172 1443   2.115
#   serious non-bonded atom clash:   172 1444   1.034
#   serious non-bonded atom clash:   174 3442   2.208
#   serious non-bonded atom clash:   175 1444   2.258
#   serious non-bonded atom clash:   176 1453   2.056
#   serious non-bonded atom clash:   176 1455   1.948
#   serious non-bonded atom clash:   177 1442   2.214
#   serious non-bonded atom clash:   177 1443   1.201
#   serious non-bonded atom clash:   177 1444   1.315
#   serious non-bonded atom clash:   178 3442   0.788
#   serious non-bonded atom clash:   179 3441   2.187
#   serious non-bonded atom clash:   179 3442   1.236
#   serious non-bonded atom clash:   180 3441   2.074
#   serious non-bonded atom clash:   180 3442   1.183
#   serious non-bonded atom clash:   181 3441   1.708
#   serious non-bonded atom clash:   181 3442   1.969
#   serious non-bonded atom clash:   181 3443   1.190
#   serious non-bonded atom clash:   182 3440   1.932
#   serious non-bonded atom clash:   182 3441   0.887
#   serious non-bonded atom clash:   182 3442   2.287
#   serious non-bonded atom clash:   182 3443   0.899
#   serious non-bonded atom clash:   183 3443   1.435
#   serious non-bonded atom clash:   184 3443   1.785
#   serious non-bonded atom clash:   185 3439   1.812
#   serious non-bonded atom clash:   186 3443   2.191
#   serious non-bonded atom clash:   187 1418   1.833
#   serious non-bonded atom clash:   208  213   2.233
#   serious non-bonded atom clash:   284 1025   2.092
#   serious non-bonded atom clash:   286 1024   2.100
#   serious non-bonded atom clash:   286 1025   0.872
#   serious non-bonded atom clash:   287 1022   1.393
#   serious non-bonded atom clash:   287 1024   1.108
#   serious non-bonded atom clash:   287 1025   1.298
#   serious non-bonded atom clash:   288 1020   2.140
#   serious non-bonded atom clash:   288 1022   1.066
#   serious non-bonded atom clash:   288 1024   1.234
#   serious non-bonded atom clash:   288 1025   1.980
#   serious non-bonded atom clash:   289 1019   1.807
#   serious non-bonded atom clash:   289 1020   0.944
#   serious non-bonded atom clash:   289 1022   1.313
#   serious non-bonded atom clash:   289 1024   2.214
#   serious non-bonded atom clash:   290 1020   2.289
#   serious non-bonded atom clash:   291 1020   1.248
#   serious non-bonded atom clash:   291 1022   1.844
#   serious non-bonded atom clash:   292 1022   2.116
#   serious non-bonded atom clash:   292 1023   1.829
#   serious non-bonded atom clash:   292 1024   1.440
#   serious non-bonded atom clash:   292 1025   2.085
#   serious non-bonded atom clash:   294 1023   1.657
#   serious non-bonded atom clash:   294 1024   1.990
#   serious non-bonded atom clash:   294 1025   2.257
#   serious non-bonded atom clash:   365  368   2.251
#   serious non-bonded atom clash:   410  517   1.327
#   serious non-bonded atom clash:   411  517   2.267
#   serious non-bonded atom clash:   412  517   0.509
#   serious non-bonded atom clash:   412  518   1.523
#   serious non-bonded atom clash:   412  529   2.145
#   serious non-bonded atom clash:   413  517   1.581
#   serious non-bonded atom clash:   413  518   0.501
#   serious non-bonded atom clash:   413  519   1.909
#   serious non-bonded atom clash:   413  529   1.089
#   serious non-bonded atom clash:   413  530   2.035
#   serious non-bonded atom clash:   413  531   2.160
#   serious non-bonded atom clash:   413  608   2.050
#   serious non-bonded atom clash:   414  518   1.175
#   serious non-bonded atom clash:   414  519   1.487
#   serious non-bonded atom clash:   414  520   2.138
#   serious non-bonded atom clash:   415  519   2.211
#   serious non-bonded atom clash:   415  520   1.600
#   serious non-bonded atom clash:   415  521   1.494
#   serious non-bonded atom clash:   415  525   2.102
#   serious non-bonded atom clash:   416  518   2.283
#   serious non-bonded atom clash:   417  518   1.681
#   serious non-bonded atom clash:   417  519   1.911
#   serious non-bonded atom clash:   417  529   1.198
#   serious non-bonded atom clash:   417  530   1.230
#   serious non-bonded atom clash:   417  531   1.864
#   serious non-bonded atom clash:   418  529   2.142
#   serious non-bonded atom clash:   418  530   1.368
#   serious non-bonded atom clash:   419  520   2.108
#   serious non-bonded atom clash:   419  522   1.699
#   serious non-bonded atom clash:   419  529   1.910
#   serious non-bonded atom clash:   419  530   2.083
#   serious non-bonded atom clash:   419  531   1.455
#   serious non-bonded atom clash:   420  522   2.025
#   serious non-bonded atom clash:   425  522   2.008
#   serious non-bonded atom clash:   425  523   2.283
#   serious non-bonded atom clash:   426  522   1.861
#   serious non-bonded atom clash:   426  523   1.572
#   serious non-bonded atom clash:   426  536   2.093
#   serious non-bonded atom clash:   426  537   1.461
#   serious non-bonded atom clash:   426  872   1.711
#   serious non-bonded atom clash:   426  873   1.488
#   serious non-bonded atom clash:   428  620   2.154
#   serious non-bonded atom clash:   428  874   1.898
#   serious non-bonded atom clash:   434  620   1.938
#   serious non-bonded atom clash:   434  874   2.207
#   serious non-bonded atom clash:   436  620   2.057
#   serious non-bonded atom clash:   436  621   1.878
#   serious non-bonded atom clash:   436  622   1.292
#   serious non-bonded atom clash:   436  874   2.131
#   serious non-bonded atom clash:   437  622   0.976
#   serious non-bonded atom clash:   438  622   1.765
#   serious non-bonded atom clash:   439  449   2.013
#   serious non-bonded atom clash:   445  622   1.513
#   serious non-bonded atom clash:   446  622   2.006
#   serious non-bonded atom clash:   529  608   1.329
#   serious non-bonded atom clash:   530  608   2.273
#   serious non-bonded atom clash:   531  608   1.036
#   serious non-bonded atom clash:   531  609   1.845
#   serious non-bonded atom clash:   531  614   2.264
#   serious non-bonded atom clash:   531  872   2.107
#   serious non-bonded atom clash:   532  608   1.838
#   serious non-bonded atom clash:   532  609   1.191
#   serious non-bonded atom clash:   532  614   1.078
#   serious non-bonded atom clash:   532  615   2.117
#   serious non-bonded atom clash:   532  616   2.183
#   serious non-bonded atom clash:   532  872   1.613
#   serious non-bonded atom clash:   533  608   2.221
#   serious non-bonded atom clash:   533  609   0.746
#   serious non-bonded atom clash:   533  610   1.329
#   serious non-bonded atom clash:   533  611   1.907
#   serious non-bonded atom clash:   533  612   1.972
#   serious non-bonded atom clash:   533  614   1.623
#   serious non-bonded atom clash:   533  615   2.022
#   serious non-bonded atom clash:   533  616   2.108
#   serious non-bonded atom clash:   534  609   2.134
#   serious non-bonded atom clash:   534  610   2.208
#   serious non-bonded atom clash:   534  611   1.582
#   serious non-bonded atom clash:   534  612   0.774
#   serious non-bonded atom clash:   534  614   2.131
#   serious non-bonded atom clash:   534  615   1.602
#   serious non-bonded atom clash:   534  616   1.587
#   serious non-bonded atom clash:   535  609   1.597
#   serious non-bonded atom clash:   535  610   0.668
#   serious non-bonded atom clash:   535  611   1.795
#   serious non-bonded atom clash:   536  614   0.974
#   serious non-bonded atom clash:   536  615   1.744
#   serious non-bonded atom clash:   536  616   1.827
#   serious non-bonded atom clash:   536  872   0.544
#   serious non-bonded atom clash:   536  873   1.582
#   serious non-bonded atom clash:   536  876   2.271
#   serious non-bonded atom clash:   537  614   2.053
#   serious non-bonded atom clash:   537  872   0.815
#   serious non-bonded atom clash:   537  873   1.161
#   serious non-bonded atom clash:   537  880   1.829
#   serious non-bonded atom clash:   537  882   2.196
#   serious non-bonded atom clash:   538  614   1.614
#   serious non-bonded atom clash:   538  615   1.213
#   serious non-bonded atom clash:   538  616   1.196
#   serious non-bonded atom clash:   538  617   1.089
#   serious non-bonded atom clash:   538  618   1.618
#   serious non-bonded atom clash:   538  872   1.838
#   serious non-bonded atom clash:   538  873   1.893
#   serious non-bonded atom clash:   538  876   1.530
#   serious non-bonded atom clash:   539  617   1.348
#   serious non-bonded atom clash:   539  618   1.580
#   serious non-bonded atom clash:   539  619   2.165
#   serious non-bonded atom clash:   539  873   2.004
#   serious non-bonded atom clash:   539  875   1.879
#   serious non-bonded atom clash:   539  876   1.085
#   serious non-bonded atom clash:   540  618   1.867
#   serious non-bonded atom clash:   540  619   1.742
#   serious non-bonded atom clash:   540  873   1.883
#   serious non-bonded atom clash:   540  874   1.821
#   serious non-bonded atom clash:   540  875   0.684
#   serious non-bonded atom clash:   540  876   1.086
#   serious non-bonded atom clash:   540  878   1.712
#   serious non-bonded atom clash:   541  619   2.193
#   serious non-bonded atom clash:   541  874   1.790
#   serious non-bonded atom clash:   541  875   1.111
#   serious non-bonded atom clash:   541  877   1.353
#   serious non-bonded atom clash:   541  878   0.547
#   serious non-bonded atom clash:   541  879   1.849
#   serious non-bonded atom clash:   542  617   1.458
#   serious non-bonded atom clash:   542  618   1.948
#   serious non-bonded atom clash:   542  619   1.987
#   serious non-bonded atom clash:   542  623   1.568
#   serious non-bonded atom clash:   542  625   1.502
#   serious non-bonded atom clash:   542  876   2.166
#   serious non-bonded atom clash:   543  617   1.492
#   serious non-bonded atom clash:   543  618   2.250
#   serious non-bonded atom clash:   543  623   0.487
#   serious non-bonded atom clash:   543  624   1.664
#   serious non-bonded atom clash:   543  625   1.081
#   serious non-bonded atom clash:   544  619   2.295
#   serious non-bonded atom clash:   544  625   1.773
#   serious non-bonded atom clash:   545  625   1.846
#   serious non-bonded atom clash:   545  626   1.966
#   serious non-bonded atom clash:   545  628   1.634
#   serious non-bonded atom clash:   545  629   1.260
#   serious non-bonded atom clash:   546  625   1.938
#   serious non-bonded atom clash:   546  626   1.473
#   serious non-bonded atom clash:   546  627   1.552
#   serious non-bonded atom clash:   546  628   1.787
#   serious non-bonded atom clash:   547  628   2.242
#   serious non-bonded atom clash:   547  629   1.280
#   serious non-bonded atom clash:   549  628   2.202
#   serious non-bonded atom clash:   549  629   1.635
#   serious non-bonded atom clash:   549  631   2.292
#   serious non-bonded atom clash:   553  631   2.107
#   serious non-bonded atom clash:   554  631   1.170
#   serious non-bonded atom clash:   554  632   2.168
#   serious non-bonded atom clash:   554  634   1.602
#   serious non-bonded atom clash:   554  636   1.973
#   serious non-bonded atom clash:   556  639   2.078
#   serious non-bonded atom clash:   558  638   1.924
#   serious non-bonded atom clash:   558  639   2.239
#   serious non-bonded atom clash:   567  641   2.285
#   serious non-bonded atom clash:   575  583   2.037
#   serious non-bonded atom clash:   586  663   2.186
#   serious non-bonded atom clash:   587  661   2.096
#   serious non-bonded atom clash:   587  663   1.117
#   serious non-bonded atom clash:   587  665   1.992
#   serious non-bonded atom clash:   589  665   2.003
#   serious non-bonded atom clash:   589  666   1.553
#   serious non-bonded atom clash:   589  673   2.145
#   serious non-bonded atom clash:   590  662   2.234
#   serious non-bonded atom clash:   590  664   1.018
#   serious non-bonded atom clash:   590  665   1.434
#   serious non-bonded atom clash:   590  666   1.995
#   serious non-bonded atom clash:   590  673   1.443
#   serious non-bonded atom clash:   591  664   1.562
#   serious non-bonded atom clash:   592  662   2.296
#   serious non-bonded atom clash:   592  664   2.001
#   serious non-bonded atom clash:   612  615   2.232
#   serious non-bonded atom clash:   612  616   2.214
#   serious non-bonded atom clash:   614  872   1.341
#   serious non-bonded atom clash:   615  872   2.268
#   serious non-bonded atom clash:   617  876   1.819
#   serious non-bonded atom clash:   618  875   1.992
#   serious non-bonded atom clash:   618  876   0.992
#   serious non-bonded atom clash:   619  874   1.801
#   serious non-bonded atom clash:   619  875   1.294
#   serious non-bonded atom clash:   619  876   1.796
#   serious non-bonded atom clash:   619  878   2.226
#   serious non-bonded atom clash:   620  874   1.176
#   serious non-bonded atom clash:   620  875   1.993
#   serious non-bonded atom clash:   620  879   2.185
#   serious non-bonded atom clash:   621  874   1.841
#   serious non-bonded atom clash:   621  879   1.730
#   serious non-bonded atom clash:   660  671   2.028
#   serious non-bonded atom clash:   662  671   1.876
#   serious non-bonded atom clash:   664  673   1.984
#   serious non-bonded atom clash:   805  815   2.013
#   serious non-bonded atom clash:   829  836   2.161
#   serious non-bonded atom clash:   831  836   2.180
#   serious non-bonded atom clash:   907  920   2.035
#   serious non-bonded atom clash:   909  920   1.875
#   serious non-bonded atom clash:   910  920   2.299
#   serious non-bonded atom clash:   910  922   2.120
#   serious non-bonded atom clash:   913  964   1.681
#   serious non-bonded atom clash:   913  965   1.784
#   serious non-bonded atom clash:   915  964   2.293
#   serious non-bonded atom clash:   967  976   1.332
#   serious non-bonded atom clash:   968  976   2.261
#   serious non-bonded atom clash:   969  977   1.881
#   serious non-bonded atom clash:   970  979   1.313
#   serious non-bonded atom clash:   970  981   1.730
#   serious non-bonded atom clash:   970 1103   1.429
#   serious non-bonded atom clash:   970 1105   1.845
#   serious non-bonded atom clash:   971  977   0.685
#   serious non-bonded atom clash:   971  978   1.287
#   serious non-bonded atom clash:   971  979   1.607
#   serious non-bonded atom clash:   971  981   2.297
#   serious non-bonded atom clash:   971 1103   1.355
#   serious non-bonded atom clash:   971 1104   1.954
#   serious non-bonded atom clash:   971 1105   1.781
#   serious non-bonded atom clash:   972  977   2.207
#   serious non-bonded atom clash:   972  978   2.176
#   serious non-bonded atom clash:   972  979   2.289
#   serious non-bonded atom clash:   972  981   2.271
#   serious non-bonded atom clash:   972 1100   1.353
#   serious non-bonded atom clash:   972 1101   1.042
#   serious non-bonded atom clash:   972 1103   1.475
#   serious non-bonded atom clash:   972 1104   1.087
#   serious non-bonded atom clash:   972 1105   1.543
#   serious non-bonded atom clash:   973  977   1.644
#   serious non-bonded atom clash:   973  978   1.563
#   serious non-bonded atom clash:   974  980   1.651
#   serious non-bonded atom clash:   974  981   1.179
#   serious non-bonded atom clash:   974  982   1.928
#   serious non-bonded atom clash:   974 1103   2.251
#   serious non-bonded atom clash:   974 1105   1.669
#   serious non-bonded atom clash:   975  979   2.017
#   serious non-bonded atom clash:   975  981   1.065
#   serious non-bonded atom clash:   975  982   0.865
#   serious non-bonded atom clash:   975  983   1.537
#   serious non-bonded atom clash:   975  985   2.056
#   serious non-bonded atom clash:   975  986   2.290
#   serious non-bonded atom clash:   975 1105   1.813
#   serious non-bonded atom clash:   977 1103   1.685
#   serious non-bonded atom clash:   977 1105   2.098
#   serious non-bonded atom clash:   979 1103   1.798
#   serious non-bonded atom clash:   979 1105   1.184
#   serious non-bonded atom clash:   980 1105   2.191
#   serious non-bonded atom clash:   981 1100   2.008
#   serious non-bonded atom clash:   981 1103   1.553
#   serious non-bonded atom clash:   981 1105   0.813
#   serious non-bonded atom clash:   982 1105   2.010
#   serious non-bonded atom clash:   997 1061   2.273
#   serious non-bonded atom clash:   997 1063   1.513
#   serious non-bonded atom clash:   997 1064   1.853
#   serious non-bonded atom clash:   998 1059   1.503
#   serious non-bonded atom clash:   998 1060   1.633
#   serious non-bonded atom clash:   998 1061   1.686
#   serious non-bonded atom clash:   998 1062   1.939
#   serious non-bonded atom clash:   998 1063   1.985
#   serious non-bonded atom clash:   998 1064   2.098
#   serious non-bonded atom clash:   998 1332   2.078
#   serious non-bonded atom clash:  1052 1055   2.131
#   serious non-bonded atom clash:  1059 1332   2.105
#   serious non-bonded atom clash:  1060 1311   1.713
#   serious non-bonded atom clash:  1060 1331   1.940
#   serious non-bonded atom clash:  1060 1332   0.858
#   serious non-bonded atom clash:  1061 1074   2.133
#   serious non-bonded atom clash:  1062 1330   1.676
#   serious non-bonded atom clash:  1062 1331   1.071
#   serious non-bonded atom clash:  1062 1332   1.703
#   serious non-bonded atom clash:  1063 1074   1.809
#   serious non-bonded atom clash:  1064 1330   2.219
#   serious non-bonded atom clash:  1064 1331   2.295
#   serious non-bonded atom clash:  1095 1326   2.010
#   serious non-bonded atom clash:  1103 1112   1.880
#   serious non-bonded atom clash:  1104 1112   1.872
#   serious non-bonded atom clash:  1127 1199   1.741
#   serious non-bonded atom clash:  1127 1200   2.088
#   serious non-bonded atom clash:  1127 1201   0.988
#   serious non-bonded atom clash:  1128 1194   1.999
#   serious non-bonded atom clash:  1128 1197   1.655
#   serious non-bonded atom clash:  1128 1198   2.061
#   serious non-bonded atom clash:  1128 1199   1.309
#   serious non-bonded atom clash:  1128 1200   1.747
#   serious non-bonded atom clash:  1128 1201   1.342
#   serious non-bonded atom clash:  1129 1194   1.240
#   serious non-bonded atom clash:  1129 1197   1.795
#   serious non-bonded atom clash:  1129 1198   0.870
#   serious non-bonded atom clash:  1129 1199   2.033
#   serious non-bonded atom clash:  1129 1200   1.232
#   serious non-bonded atom clash:  1129 1201   1.785
#   serious non-bonded atom clash:  1130 1192   2.165
#   serious non-bonded atom clash:  1130 1193   1.252
#   serious non-bonded atom clash:  1130 1194   0.551
#   serious non-bonded atom clash:  1130 1197   1.950
#   serious non-bonded atom clash:  1130 1198   1.353
#   serious non-bonded atom clash:  1131 1192   1.605
#   serious non-bonded atom clash:  1131 1193   1.572
#   serious non-bonded atom clash:  1131 1194   1.824
#   serious non-bonded atom clash:  1131 1198   2.158
#   serious non-bonded atom clash:  1133 1191   2.179
#   serious non-bonded atom clash:  1133 1192   0.715
#   serious non-bonded atom clash:  1133 1193   1.737
#   serious non-bonded atom clash:  1140 1209   1.800
#   serious non-bonded atom clash:  1157 1161   2.192
#   serious non-bonded atom clash:  1177 1179   1.981
#   serious non-bonded atom clash:  1195 1271   1.558
#   serious non-bonded atom clash:  1196 1271   1.902
#   serious non-bonded atom clash:  1224 1230   2.052
#   serious non-bonded atom clash:  1254 1257   2.247
#   serious non-bonded atom clash:  1308 1332   2.111
#   serious non-bonded atom clash:  1310 1331   2.115
#   serious non-bonded atom clash:  1310 1332   1.591
#   serious non-bonded atom clash:  1311 1332   1.144
#   serious non-bonded atom clash:  1382 1385   2.247
#   serious non-bonded atom clash:  1690 3773   1.476
#   serious non-bonded atom clash:  2726 2845   2.226
#   serious non-bonded atom clash:  2726 2846   1.694
#   serious non-bonded atom clash:  2727 2845   2.158
#   serious non-bonded atom clash:  2727 2846   2.119
#   serious non-bonded atom clash:  2728 2845   1.433
#   serious non-bonded atom clash:  2728 2846   2.106
#   serious non-bonded atom clash:  2729 2844   1.911
#   serious non-bonded atom clash:  2729 2845   1.591
#   serious non-bonded atom clash:  2729 2846   1.681
#   serious non-bonded atom clash:  2730 2846   2.129
#   serious non-bonded atom clash:  2740 2766   2.263
#   serious non-bonded atom clash:  2837 2839   2.088
#   serious non-bonded atom clash:  3125 3128   2.248
#   serious non-bonded atom clash:  3158 3161   2.218
#   serious non-bonded atom clash:  3158 3185   2.198
#   serious non-bonded atom clash:  3833 3836   2.150
#   serious non-bonded atom clash:  3995 4000   2.249
#   serious non-bonded atom clash:  4031 4036   2.263
#   serious non-bonded atom clash:  4051 4054   2.248
#   serious non-bonded atom clash:  4053 4058   2.276
#   serious non-bonded atom clash:  4082 4087   2.261
#   serious non-bonded atom clash:  4109 4116   2.161
#   serious non-bonded atom clash:  4111 4116   2.180
#   serious non-bonded atom clash:  4132 4137   1.947
#   serious non-bonded atom clash:  4164 4171   2.161
#   serious non-bonded atom clash:  4166 4171   2.180
#   serious non-bonded atom clash:  4207 4210   2.247
#   serious non-bonded atom clash:  4217 4226   1.988
#   serious non-bonded atom clash:  4219 4226   2.150
#   serious non-bonded atom clash:  4219 4228   1.960
#   serious non-bonded atom clash:  4220 4226   1.726
#   serious non-bonded atom clash:  4220 4228   2.245
#   serious non-bonded atom clash:  4243 4250   2.161
#   serious non-bonded atom clash:  4245 4250   2.180
#   serious non-bonded atom clash:  4277 4285   2.037
#   serious non-bonded atom clash:  4297 4303   1.936
#   serious non-bonded atom clash:  4364 4370   1.936
#   serious non-bonded atom clash:  4465 4468   2.247
#   serious non-bonded atom clash:  4562 4572   2.013
#   serious non-bonded atom clash:  4661 4666   2.263
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:   300   59   62   65   78   78   91  169  273  425  346  423  540  646  669
#
#
# << end of ENERGY.
#
# >> Summary of successfully produced models:
# Filename                          molpdf
# ----------------------------------------
# 7vvk_fill.B99990001.pdb          2.11227
#
# AutoModel__W> Topology and/or parameter libraries already in memory. These will
#                 be used instead of the AutoModel defaults. If this is not what you
#                 want, clear them before creating the AutoModel object with
#                 env.libs.topology.clear() and env.libs.parameters.clear()
# readlinef__W> File: 7vvk_fill.B99990001.pdb, Line: 5
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: 7vvk_fill.B99990001.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: 7vvk_fill.B99990001.pdb, Line: 5
#               Modeller will only read the first 80 characters of this line.
#
# readlinef__W> File: 7vvk_fill.B99990001.pdb, Line: 6
#               Modeller will only read the first 80 characters of this line.
#
#   #      ALGNMT CODE
#
#   1  7vvk_fill
#   2  7vvk_fill
# 1008 atoms selected for loop refinement
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:     5034     4161
# preppdf_457W> Both soft sphere and statistical potential terms selected.
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      593
# Number of all, selected real atoms                :     4677    1008
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :     4161    4161
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):    15011
# Dynamic pairs routine                             : 5, NATM_SEL x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    7.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :     9810532.0000
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    1037      10     10   5.043   5.043     0.97562E+07   1.000
#  2 Bond angle potential               :    1418      34     35  10.046  10.046      3107.9       1.000
#  3 Stereochemical cosine torsion poten:     788       3    114  55.501  55.501      452.68       1.000
#  4 Stereochemical improper torsion pot:     384      19     19  12.913  12.913      1407.6       1.000
#  5 Soft-sphere overlap restraints     :   15011     375    417   0.159   0.159      44865.       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :       0       0      0   0.000   0.000      0.0000       1.000
# 10 Distance restraints 2 (N-O)        :       0       0      0   0.000   0.000      0.0000       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     137       5      7  25.006  25.006      1011.1       1.000
# 14 Sidechain Chi_1 dihedral restraints:     106       0      0 104.710 104.710      33.536       1.000
# 15 Sidechain Chi_2 dihedral restraints:      80       0      0  55.889  55.889      6.0515       1.000
# 16 Sidechain Chi_3 dihedral restraints:      50       0      0 114.316 114.316      29.321       1.000
# 17 Sidechain Chi_4 dihedral restraints:      19       0      0  68.523  68.523      9.7892       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :       0       0      0   0.000   0.000      0.0000       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:     142     114     88  67.303 159.505      535.24       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :       0       0      0   0.000   0.000      0.0000       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :   15011       0    613   1.884   1.884      2826.3       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature  1                           : Bond length potential
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1     47  53K  54E C   N     401  403   21.32    1.35   19.98  707.40    1.35   19.98  707.40
#     2    162  68G  69W C   N     515  517   45.98    1.35   44.64 1580.70    1.35   44.64 1580.70
#     3    256  80K  81D C   N     606  608   36.08    1.35   34.74 1230.16    1.35   34.74 1230.16
#     4    528 113D 114H C   N     870  872  102.54    1.35  101.19 3583.41    1.35  101.19 3583.41
#     5    623 125E 126V C   N     960  962   27.87    1.35   26.53  939.43    1.35   26.53  939.43
#     6    637 127V 128A C   N     974  976    2.94    1.35    1.59   56.40    1.35    1.59   56.40
#     7    687 162R 163T C   N    1266 1268   21.78    1.35   20.44  723.67    1.35   20.44  723.67
#     8    734 178T 179R C   N    1399 1401    8.52    1.35    7.18  254.11    1.35    7.18  254.11
#     9    974 277G 278Y C   N    2178 2180  105.62    1.35  104.28 3692.70    1.35  104.28 3692.70
#    10   1029 397C 398D C   N    3152 3154   23.27    1.35   21.93  776.42    1.35   21.93  776.42
#
# -------------------------------------------------------------------------------------------------
#
# Feature  2                           : Bond angle potential
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   1099  54E  53K N   C     403  401  160.51  122.50   38.01   10.92  122.50   38.01   10.92
#     2   1253  69W  68G N   C     517  515  147.32  122.50   24.82    7.13  122.50   24.82    7.13
#     3   1380  81D  80K N   C     608  606  169.48  122.50   46.98   13.50  122.50   46.98   13.50
#     4   1748 114H 113D N   C     872  870  174.53  122.50   52.03   14.95  122.50   52.03   14.95
#     5   1880 126V 125E N   C     962  960  168.01  122.50   45.51   13.08  122.50   45.51   13.08
#     6   1900 128A 127V N   C     976  974  154.67  122.50   32.17    9.24  122.50   32.17    9.24
#     7   1970 163T 162R N   C    1268 1266  174.44  122.50   51.94   14.93  122.50   51.94   14.93
#     8   2037 179R 178T N   C    1401 1399  176.65  122.50   54.15   15.56  122.50   54.15   15.56
#     9   2368 278Y 277G N   C    2180 2178  153.35  122.50   30.85    8.87  122.50   30.85    8.87
#    10   2444 398D 397C N   C    3154 3152  171.48  122.50   48.98   14.08  122.50   48.98   14.08
#
# -------------------------------------------------------------------------------------------------
#
# Feature  3                           : Stereochemical cosine torsion potential
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   2845  49E  49E O   C     365  364  -82.21    0.00  -82.21    4.91    0.00  -82.21    4.91
#     2   3017  80K  80K O   C     607  606  -97.27  180.00   82.73    4.92  180.00   82.73    4.92
#     3   3022  81D  81D O   C     615  614   92.98  180.00  -87.02    4.99  180.00  -87.02    4.99
#
# -------------------------------------------------------------------------------------------------
#
# Feature  4                           : Stereochemical improper torsion potentia
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   2457  49E  49E C   CA    364  358   71.04    0.00   71.04   25.01    0.00   71.04   25.01
#
# -------------------------------------------------------------------------------------------------
#
# Feature 13                           : Mainchain Omega dihedral restraints
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   3849 127V 127V CA  C     970  974  -53.43  180.00  126.57   25.31  180.00  126.57   25.31
#     2   3905 397C 397C CA  C    3149 3152 -118.26  180.00   61.74   12.35  180.00   61.74   12.35
#
# -------------------------------------------------------------------------------------------------
#
# ...
#   serious non-bonded atom clash:   537  882   2.196
#   serious non-bonded atom clash:   538  614   1.614
#   serious non-bonded atom clash:   538  615   1.213
#   serious non-bonded atom clash:   538  616   1.196
#   serious non-bonded atom clash:   538  617   1.089
#   serious non-bonded atom clash:   538  618   1.618
#   serious non-bonded atom clash:   538  872   1.838
#   serious non-bonded atom clash:   538  873   1.893
#   serious non-bonded atom clash:   538  876   1.530
#   serious non-bonded atom clash:   539  617   1.348
#   serious non-bonded atom clash:   539  618   1.580
#   serious non-bonded atom clash:   539  619   2.165
#   serious non-bonded atom clash:   539  873   2.004
#   serious non-bonded atom clash:   539  875   1.879
#   serious non-bonded atom clash:   539  876   1.085
#   serious non-bonded atom clash:   540  618   1.867
#   serious non-bonded atom clash:   540  619   1.742
#   serious non-bonded atom clash:   540  873   1.883
#   serious non-bonded atom clash:   540  874   1.821
#   serious non-bonded atom clash:   540  875   0.684
#   serious non-bonded atom clash:   540  876   1.086
#   serious non-bonded atom clash:   540  878   1.712
#   serious non-bonded atom clash:   541  619   2.193
#   serious non-bonded atom clash:   541  874   1.790
#   serious non-bonded atom clash:   541  875   1.111
#   serious non-bonded atom clash:   541  877   1.353
#   serious non-bonded atom clash:   541  878   0.547
#   serious non-bonded atom clash:   541  879   1.849
#   serious non-bonded atom clash:   542  617   1.458
#   serious non-bonded atom clash:   542  618   1.948
#   serious non-bonded atom clash:   542  619   1.987
#   serious non-bonded atom clash:   542  623   1.568
#   serious non-bonded atom clash:   542  625   1.502
#   serious non-bonded atom clash:   542  876   2.166
#   serious non-bonded atom clash:   543  617   1.492
#   serious non-bonded atom clash:   543  618   2.250
#   serious non-bonded atom clash:   543  623   0.487
#   serious non-bonded atom clash:   543  624   1.664
#   serious non-bonded atom clash:   543  625   1.081
#   serious non-bonded atom clash:   544  619   2.295
#   serious non-bonded atom clash:   544  625   1.773
#   serious non-bonded atom clash:   545  625   1.846
#   serious non-bonded atom clash:   545  626   1.966
#   serious non-bonded atom clash:   545  628   1.634
#   serious non-bonded atom clash:   545  629   1.260
#   serious non-bonded atom clash:   546  625   1.938
#   serious non-bonded atom clash:   546  626   1.473
#   serious non-bonded atom clash:   546  627   1.552
#   serious non-bonded atom clash:   546  628   1.787
#   serious non-bonded atom clash:   547  628   2.242
#   serious non-bonded atom clash:   547  629   1.280
#   serious non-bonded atom clash:   549  628   2.202
#   serious non-bonded atom clash:   549  629   1.635
#   serious non-bonded atom clash:   549  631   2.292
#   serious non-bonded atom clash:   553  631   2.107
#   serious non-bonded atom clash:   554  631   1.170
#   serious non-bonded atom clash:   554  632   2.168
#   serious non-bonded atom clash:   554  634   1.602
#   serious non-bonded atom clash:   554  636   1.973
#   serious non-bonded atom clash:   556  639   2.078
#   serious non-bonded atom clash:   558  638   1.924
#   serious non-bonded atom clash:   558  639   2.239
#   serious non-bonded atom clash:   567  641   2.285
#   serious non-bonded atom clash:   575  583   2.037
#   serious non-bonded atom clash:   586  663   2.186
#   serious non-bonded atom clash:   587  661   2.096
#   serious non-bonded atom clash:   587  663   1.117
#   serious non-bonded atom clash:   587  665   1.992
#   serious non-bonded atom clash:   589  665   2.003
#   serious non-bonded atom clash:   589  666   1.553
#   serious non-bonded atom clash:   589  673   2.145
#   serious non-bonded atom clash:   590  662   2.234
#   serious non-bonded atom clash:   590  664   1.018
#   serious non-bonded atom clash:   590  665   1.434
#   serious non-bonded atom clash:   590  666   1.995
#   serious non-bonded atom clash:   590  673   1.443
#   serious non-bonded atom clash:   591  664   1.562
#   serious non-bonded atom clash:   592  662   2.296
#   serious non-bonded atom clash:   592  664   2.001
#   serious non-bonded atom clash:   612  615   2.232
#   serious non-bonded atom clash:   612  616   2.214
#   serious non-bonded atom clash:   614  872   1.341
#   serious non-bonded atom clash:   615  872   2.268
#   serious non-bonded atom clash:   617  876   1.819
#   serious non-bonded atom clash:   618  875   1.992
#   serious non-bonded atom clash:   618  876   0.992
#   serious non-bonded atom clash:   619  874   1.801
#   serious non-bonded atom clash:   619  875   1.294
#   serious non-bonded atom clash:   619  876   1.796
#   serious non-bonded atom clash:   619  878   2.226
#   serious non-bonded atom clash:   620  874   1.176
#   serious non-bonded atom clash:   620  875   1.993
#   serious non-bonded atom clash:   620  879   2.185
#   serious non-bonded atom clash:   621  874   1.841
#   serious non-bonded atom clash:   621  879   1.730
#   serious non-bonded atom clash:   660  671   2.028
#   serious non-bonded atom clash:   662  671   1.876
#   serious non-bonded atom clash:   664  673   1.984
#   serious non-bonded atom clash:   805  815   2.013
#   serious non-bonded atom clash:   829  836   2.161
#   serious non-bonded atom clash:   831  836   2.180
#   serious non-bonded atom clash:   907  920   2.035
#   serious non-bonded atom clash:   909  920   1.875
#   serious non-bonded atom clash:   910  920   2.299
#   serious non-bonded atom clash:   910  922   2.120
#   serious non-bonded atom clash:   913  964   1.681
#   serious non-bonded atom clash:   913  965   1.784
#   serious non-bonded atom clash:   915  964   2.293
#   serious non-bonded atom clash:   967  976   1.332
#   serious non-bonded atom clash:   968  976   2.261
#   serious non-bonded atom clash:   969  977   1.881
#   serious non-bonded atom clash:   970  979   1.313
#   serious non-bonded atom clash:   970  981   1.730
#   serious non-bonded atom clash:   970 1103   1.429
#   serious non-bonded atom clash:   970 1105   1.845
#   serious non-bonded atom clash:   971  977   0.685
#   serious non-bonded atom clash:   971  978   1.287
#   serious non-bonded atom clash:   971  979   1.607
#   serious non-bonded atom clash:   971  981   2.297
#   serious non-bonded atom clash:   971 1103   1.355
#   serious non-bonded atom clash:   971 1104   1.954
#   serious non-bonded atom clash:   971 1105   1.781
#   serious non-bonded atom clash:   972  977   2.207
#   serious non-bonded atom clash:   972  978   2.176
#   serious non-bonded atom clash:   972  979   2.289
#   serious non-bonded atom clash:   972  981   2.271
#   serious non-bonded atom clash:   972 1100   1.353
#   serious non-bonded atom clash:   972 1101   1.042
#   serious non-bonded atom clash:   972 1103   1.475
#   serious non-bonded atom clash:   972 1104   1.087
#   serious non-bonded atom clash:   972 1105   1.543
#   serious non-bonded atom clash:   973  977   1.644
#   serious non-bonded atom clash:   973  978   1.563
#   serious non-bonded atom clash:   974  980   1.651
#   serious non-bonded atom clash:   974  981   1.179
#   serious non-bonded atom clash:   974  982   1.928
#   serious non-bonded atom clash:   974 1103   2.251
#   serious non-bonded atom clash:   974 1105   1.669
#   serious non-bonded atom clash:   975  979   2.017
#   serious non-bonded atom clash:   975  981   1.065
#   serious non-bonded atom clash:   975  982   0.865
#   serious non-bonded atom clash:   975  983   1.537
#   serious non-bonded atom clash:   975  985   2.056
#   serious non-bonded atom clash:   975  986   2.290
#   serious non-bonded atom clash:   975 1105   1.813
#   serious non-bonded atom clash:   977 1103   1.685
#   serious non-bonded atom clash:   977 1105   2.098
#   serious non-bonded atom clash:   979 1103   1.798
#   serious non-bonded atom clash:   979 1105   1.184
#   serious non-bonded atom clash:   980 1105   2.191
#   serious non-bonded atom clash:   981 1100   2.008
#   serious non-bonded atom clash:   981 1103   1.553
#   serious non-bonded atom clash:   981 1105   0.813
#   serious non-bonded atom clash:   982 1105   2.010
#   serious non-bonded atom clash:   997 1061   2.273
#   serious non-bonded atom clash:   997 1063   1.513
#   serious non-bonded atom clash:   997 1064   1.853
#   serious non-bonded atom clash:   998 1059   1.503
#   serious non-bonded atom clash:   998 1060   1.633
#   serious non-bonded atom clash:   998 1061   1.686
#   serious non-bonded atom clash:   998 1062   1.939
#   serious non-bonded atom clash:   998 1063   1.985
#   serious non-bonded atom clash:   998 1064   2.098
#   serious non-bonded atom clash:   998 1332   2.078
#   serious non-bonded atom clash:  1052 1055   2.131
#   serious non-bonded atom clash:  1059 1332   2.105
#   serious non-bonded atom clash:  1060 1311   1.713
#   serious non-bonded atom clash:  1060 1331   1.940
#   serious non-bonded atom clash:  1060 1332   0.858
#   serious non-bonded atom clash:  1061 1074   2.133
#   serious non-bonded atom clash:  1062 1330   1.676
#   serious non-bonded atom clash:  1062 1331   1.071
#   serious non-bonded atom clash:  1062 1332   1.703
#   serious non-bonded atom clash:  1063 1074   1.809
#   serious non-bonded atom clash:  1064 1330   2.219
#   serious non-bonded atom clash:  1064 1331   2.295
#   serious non-bonded atom clash:  1095 1326   2.010
#   serious non-bonded atom clash:  1103 1112   1.880
#   serious non-bonded atom clash:  1104 1112   1.872
#   serious non-bonded atom clash:  1127 1199   1.741
#   serious non-bonded atom clash:  1127 1200   2.088
#   serious non-bonded atom clash:  1127 1201   0.988
#   serious non-bonded atom clash:  1128 1194   1.999
#   serious non-bonded atom clash:  1128 1197   1.655
#   serious non-bonded atom clash:  1128 1198   2.061
#   serious non-bonded atom clash:  1128 1199   1.309
#   serious non-bonded atom clash:  1128 1200   1.747
#   serious non-bonded atom clash:  1128 1201   1.342
#   serious non-bonded atom clash:  1129 1194   1.240
#   serious non-bonded atom clash:  1129 1197   1.795
#   serious non-bonded atom clash:  1129 1198   0.870
#   serious non-bonded atom clash:  1129 1199   2.033
#   serious non-bonded atom clash:  1129 1200   1.232
#   serious non-bonded atom clash:  1129 1201   1.785
#   serious non-bonded atom clash:  1130 1192   2.165
#   serious non-bonded atom clash:  1130 1193   1.252
#   serious non-bonded atom clash:  1130 1194   0.551
#   serious non-bonded atom clash:  1130 1197   1.950
#   serious non-bonded atom clash:  1130 1198   1.353
#   serious non-bonded atom clash:  1131 1192   1.605
#   serious non-bonded atom clash:  1131 1193   1.572
#   serious non-bonded atom clash:  1131 1194   1.824
#   serious non-bonded atom clash:  1131 1198   2.158
#   serious non-bonded atom clash:  1133 1191   2.179
#   serious non-bonded atom clash:  1133 1192   0.715
#   serious non-bonded atom clash:  1133 1193   1.737
#   serious non-bonded atom clash:  1140 1209   1.800
#   serious non-bonded atom clash:  1157 1161   2.192
#   serious non-bonded atom clash:  1177 1179   1.981
#   serious non-bonded atom clash:  1195 1271   1.558
#   serious non-bonded atom clash:  1196 1271   1.902
#   serious non-bonded atom clash:  1224 1230   2.052
#   serious non-bonded atom clash:  1254 1257   2.247
#   serious non-bonded atom clash:  1308 1332   2.111
#   serious non-bonded atom clash:  1310 1331   2.115
#   serious non-bonded atom clash:  1310 1332   1.591
#   serious non-bonded atom clash:  1311 1332   1.144
#   serious non-bonded atom clash:  1382 1385   2.247
#   serious non-bonded atom clash:  1690 3773   1.476
#   serious non-bonded atom clash:  2204 2783   2.033
#   serious non-bonded atom clash:  2726 2845   2.226
#   serious non-bonded atom clash:  2726 2846   1.694
#   serious non-bonded atom clash:  2727 2845   2.158
#   serious non-bonded atom clash:  2727 2846   2.119
#   serious non-bonded atom clash:  2728 2845   1.433
#   serious non-bonded atom clash:  2728 2846   2.106
#   serious non-bonded atom clash:  2729 2844   1.911
#   serious non-bonded atom clash:  2729 2845   1.591
#   serious non-bonded atom clash:  2729 2846   1.681
#   serious non-bonded atom clash:  2730 2846   2.129
#   serious non-bonded atom clash:  2740 2766   2.263
#   serious non-bonded atom clash:  2837 2839   2.088
#   serious non-bonded atom clash:  3125 3128   2.248
#   serious non-bonded atom clash:  3158 3161   2.218
#   serious non-bonded atom clash:  3158 3185   2.198
#   serious non-bonded atom clash:  3833 3836   2.150
#   serious non-bonded atom clash:  3995 4000   2.249
#   serious non-bonded atom clash:  4031 4036   2.263
#   serious non-bonded atom clash:  4051 4054   2.248
#   serious non-bonded atom clash:  4053 4058   2.276
#   serious non-bonded atom clash:  4082 4087   2.261
#   serious non-bonded atom clash:  4109 4116   2.161
#   serious non-bonded atom clash:  4111 4116   2.180
#   serious non-bonded atom clash:  4132 4137   1.947
#   serious non-bonded atom clash:  4164 4171   2.161
#   serious non-bonded atom clash:  4166 4171   2.180
#   serious non-bonded atom clash:  4207 4210   2.247
#   serious non-bonded atom clash:  4217 4226   1.988
#   serious non-bonded atom clash:  4219 4226   2.150
#   serious non-bonded atom clash:  4219 4228   1.960
#   serious non-bonded atom clash:  4220 4226   1.726
#   serious non-bonded atom clash:  4220 4228   2.245
#   serious non-bonded atom clash:  4243 4250   2.161
#   serious non-bonded atom clash:  4245 4250   2.180
#   serious non-bonded atom clash:  4277 4285   2.037
#   serious non-bonded atom clash:  4297 4303   1.936
#   serious non-bonded atom clash:  4364 4370   1.936
#   serious non-bonded atom clash:  4465 4468   2.247
#   serious non-bonded atom clash:  4562 4572   2.013
#   serious non-bonded atom clash:  4661 4666   2.263
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:   301   59   62   65   78   78   91  169  273  426  347  423  540  646  669
#
#
# << end of ENERGY.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
# preppdf_457W> Both soft sphere and statistical potential terms selected.
